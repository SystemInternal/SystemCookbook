# %% [markdown]
# # System API Synthesis Demo Notebook
#
# This notebook provides basic examples of how to use System's API to conduct synthesis. Full documentation is available on our [API documentation site](https://api-docs.system.com/).
#
# Running these examples requires you to have an API key, provided by System. Please contact us at [api@system.com](mailto:api@system.com) if you are interested in exploring our public API.

# %% [markdown]
# ## Setup Notebook

# %% [markdown]
# ### Import libraries and define helper functions

# %%
# !pip install api-client==1.45.0 --extra-index-url https://pypi.fury.io/systeminc/
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.fury.io/systeminc/
# Collecting api-client==1.45.0
#   Downloading https://pypi.fury.io/systeminc/-/ver_TiZ6p/api_client-1.45.0-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 30.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from api-client==1.45.0) (2.8.2)
# Collecting typing-extensions>=4.7.1
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting pydantic>=2
#   Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 47.5 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<2.1.0,>=1.25.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from api-client==1.45.0) (1.26.12)
# Collecting pydantic-core==2.20.1
#   Downloading pydantic_core-2.20.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 147.2 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil->api-client==1.45.0) (1.16.0)
# Installing collected packages: typing-extensions, annotated-types, pydantic-core, pydantic, api-client
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Not uninstalling typing-extensions at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.2
#     Not uninstalling pydantic at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'pydantic'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.1.5 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.8.2 which is incompatible.
# spacy 3.4.2 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.8.2 which is incompatible.
# confection 0.0.3 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.8.2 which is incompatible.
# Successfully installed annotated-types-0.7.0 api-client-1.45.0 pydantic-2.8.2 pydantic-core-2.20.1 typing-extensions-4.12.2
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import api_client
import os
import pandas as pd
import json

# %%
import math

def fetch_all_paginated_data(fetch_function, job_id, page_size=1000):
    """
    Fetches all data using pagination.
    
    :param fetch_function: The API function to call
    :param job_id: The job ID for the search
    :param page_size: Number of items to fetch per page
    :return: List of all fetched data
    """
    all_data = []
    total = None
    offset = 0

    while total is None or offset < total:
        response = fetch_function(job_id, include_total=True, limit=page_size, offset=offset)
        all_data.extend(response.data)
        
        if total is None:
            total = response.total
        
        offset += page_size
        
    return all_data

# %% [markdown]
# ### Create a service client and initialize endpoints

# %%
# %env YOUR_API_KEY=<YOUR_API_KEY>
# Out:
# env: YOUR_API_KEY=<YOUR_API_KEY>

# %%
from api_client import ApiClient, SynthesisApi, Configuration

API_KEY = os.environ.get("YOUR_API_KEY")
if not API_KEY:
	raise ValueError("API key is missing")

system_client = ApiClient(header_name="x-api-key", header_value=API_KEY)

synthesis_api = SynthesisApi(system_client)

# %% [markdown]
# ##  Initiate a pubmed query search

# %%
from api_client import PubmedSearchSynthesisInput

query="kras"
job_id = synthesis_api.synthesize_pubmed_search(pubmed_search_synthesis_input=PubmedSearchSynthesisInput(query=query))

# %%
print(f"Synthesis started with job_id: {job_id}")
# Out:
# Synthesis started with job_id: TZJiTbX_pm

# %% [markdown]
# ## Get Synthesis and Statements

# %% [markdown]
# ### Check on Synthesis status

# %%
from api_client import JobStatus
import time
from IPython.display import clear_output

# Assuming synthesis_api and job_id are already defined
start_time = time.time()
time_taken = time.time() - start_time

status = synthesis_api.get_pubmed_search_synthesis_by_id(job_id)
running_statuses = [
    JobStatus.ACCEPTED, JobStatus.CLUSTERING, JobStatus.SYNTHESIZING, JobStatus.SYNTHESIS_RUNNING
]

while status.status in running_statuses:
    # Clear the previous output
    clear_output(wait=True)
    
    # Calculate time taken
    time_taken = time.time() - start_time
    
    # Display current status and time taken
    print(f"Current status: {status}")
    print(f"Time taken: {time_taken:.2f} seconds")
    
    # Wait for a short interval before checking again
    time.sleep(1)
    
    # Update the status
    status = synthesis_api.get_pubmed_search_synthesis_by_id(job_id)

# After the loop ends, show the final status
print(f"Final status: {status.status}")
print(f"Total time taken: {time_taken:.2f} seconds")
# Out:
# Current status: id='TZJiTbX_pm' status=<JobStatus.SYNTHESIZING: 'synthesizing'> created_at=datetime.datetime(2024, 8, 8, 2, 40, 55, 553485) updated_at=datetime.datetime(2024, 8, 8, 2, 41, 5, 622877) user_query='kras' pubmed_query='"kras"[All Fields]' clustering_finished=datetime.datetime(2024, 8, 8, 2, 41, 4, 618668) synthesis_finished=None
# Time taken: 18.37 seconds
# Final status: synthesis_success
# Total time taken: 18.37 seconds

# %% [markdown]
# ### Get Synthesis and Supporting Resources

# %%
synthesis = synthesis_api.get_synthesis_from_pubmed_search(job_id)
statements = fetch_all_paginated_data(synthesis_api.get_statements_from_pubmed_search, job_id)
studies = fetch_all_paginated_data(synthesis_api.get_studies_from_pubmed_search, job_id)
statistical_findings = fetch_all_paginated_data(synthesis_api.get_statistical_findings_from_pubmed_search, job_id)
mechanistic_findings = fetch_all_paginated_data(synthesis_api.get_mechanistic_findings_from_pubmed_search, job_id)

studies_df = pd.DataFrame([json.loads(study.json()) for study in studies])
statistical_findings_df = pd.DataFrame([json.loads(finding.json()) for finding in statistical_findings])
mechanistic_findings_df = pd.DataFrame([json.loads(finding.json()) for finding in mechanistic_findings])
statements_df = pd.DataFrame([json.loads(statement.json()) for statement in statements])

# %% [markdown]
# # Show Synthesis Output

# %%
from IPython.display import display, HTML

import re

def extract_citations(text):
    citations = re.findall(r'\[(\d+)\]', text)
    return set(citations)

citations = set()
for result in synthesis.summaries:
    theme = result['theme']
    summary = result['summary'].replace('\n', '<br>')
    citations.update(extract_citations(result['summary']))
    
    output = f"""
    <div style="margin-bottom: 20px;">
        <strong>Theme:</strong> {theme}<br><br>
        <strong>Summary:</strong><br>
        {summary}
    </div>
    <hr>
    """
    display(HTML(output))
# Out:
#     <div style="margin-bottom: 20px;">
#         <strong>Theme:</strong> Overview of KRAS<br><br>
#         <strong>Summary:</strong><br>
#         KRAS is a gene that plays a crucial role in cell signaling pathways that control cell growth and division. It is frequently mutated in various cancers, which can influence patient outcomes and treatment responses. For instance, studies suggest that KRAS mutations are associated with mixed effects on overall survival across different types of cancer, including non-small-cell lung cancer (NSCLC) and pancreatic ductal adenocarcinoma (PDAC) [1][5]. In colorectal cancer, KRAS testing has been linked to prognosis, but the strength of this association varies [2]. Furthermore, specific mutations, like the KRAS G13D variant, have been identified in cases of metastatic colorectal tumors [4]. Overall, while there are established associations between KRAS mutations and cancer prognosis, the variability in findings indicates that the impact of these mutations can differ significantly among patients and cancer types.
#     </div>
#     <hr>
#     <div style="margin-bottom: 20px;">
#         <strong>Theme:</strong> Function of KRAS<br><br>
#         <strong>Summary:</strong><br>
#         KRAS plays a significant role in various cellular functions and processes within the body. It is involved in regulating transcription, which is the process by which genes are turned on to produce RNA, and subsequently proteins necessary for cell function. This regulation affects numerous pathways including those related to apoptosis, epithelial to mesenchymal transition, and response to drugs, among others [205]. KRAS is known to positively regulate the activation of several key signaling pathways including HNRNP, TGFB, NFkappaB, and ERK, which are critical for cell proliferation and survival [209]. Additionally, KRAS influences the expression of other proteins such as Cyclin D1, Ki-67, and Bcl2, which are associated with cell cycle regulation, proliferation, and apoptosis [245][250][276]. The interaction of KRAS with different molecules, such as GTP, is essential for its activity, as it binds GTP to drive cellular signaling cascades [57]. Furthermore, KRAS affects the levels of various cyclins and signaling molecules, thereby impacting the progression of the cell cycle and tumor development [111]. Overall, the functions of KRAS are central to the regulation of many processes that contribute to cancer progression and cellular homeostasis.
#     </div>
#     <hr>
#     <div style="margin-bottom: 20px;">
#         <strong>Theme:</strong> KRAS Mutations<br><br>
#         <strong>Summary:</strong><br>
#         KRAS mutations play a significant role in the prognosis and treatment of various cancers. In the context of metastatic colorectal cancer, KRAS mutations are generally associated with increases in progression-free survival; however, the overall strength of this effect can vary across studies [6]. Conversely, in non-small-cell lung cancer (NSCLC) patients, KRAS mutations are associated with decreases in overall survival, indicating that the impact of these mutations can differ based on the type of cancer [7][15]. Moreover, KRAS mutations are linked to overall survival in advanced colorectal cancer patients, although the strength of this association is again mixed [19]. In addition to survival outcomes, KRAS mutations contribute to disease dissemination in colon cancer patients [21]. KRAS mutations are also correlated with increases in tumor grade and stage, suggesting that these mutations might indicate a more aggressive cancer phenotype [52][56]. Furthermore, the prevalence of KRAS mutations is noted to be higher among smokers, although the strength of this correlation is mixed [61]. Overall, KRAS mutations serve as a critical biomarker in cancer pathology, influencing not only the disease progression but also the potential therapeutic targets available for treatment.
#     </div>
#     <hr>
#     <div style="margin-bottom: 20px;">
#         <strong>Theme:</strong> Associated Cancers<br><br>
#         <strong>Summary:</strong><br>
#         The KRAS gene plays a significant role in various cancers, particularly non-small-cell lung cancer (NSCLC) and pancreatic cancer. KRAS mutations, specifically the G12D mutation, are associated with an increased rate of metastatic tumors, highlighting their aggressive nature in cancer progression [257]. Additionally, KRAS is linked to pancreatic cancer diagnoses, where its mutation is notably common [307]. In colorectal cancer, Kirsten Ras mutations correlate with decreased disease-specific survival, indicating a poorer prognosis for affected individuals [615]. Furthermore, specific mutations, such as G12C, are associated with increased frequencies of metastasectomies and ablations, suggesting a more challenging disease course [488]. In NSCLC, KRAS mutations are associated with increased radioresistance, complicating treatment options for this patient population [873]. These associations underscore the importance of KRAS as a key player in the pathology of several cancer types, influencing both survival outcomes and treatment responses.
#     </div>
#     <hr>
#     <div style="margin-bottom: 20px;">
#         <strong>Theme:</strong> Pathway Interactions<br><br>
#         <strong>Summary:</strong><br>
#         KRAS is a crucial player in several signaling pathways that regulate cell growth and survival. One of its key interactions is with RAF, a protein that plays a significant role in the MAPK (Mitogen-Activated Protein Kinase) pathway, where KRAS binds to RAF to activate downstream signaling [86]. In addition to RAF, KRAS is also activated by various factors including MEK, ERK, and multiple receptor tyrosine kinases (RTKs), indicating its pivotal role in cellular signaling networks [124]. Furthermore, KRAS interacts with a variety of other proteins such as BRAF, MYC, and TP53, illustrating its extensive network of interactions that influence cell behavior [159]. This network is essential for the regulation of processes like cell proliferation and survival, making KRAS a vital component of tumorigenesis pathways in various cancers [548]. Overall, the interactions of KRAS with other key proteins and pathways underscore its importance in cancer biology and potential therapeutic targeting.
#     </div>
#     <hr>
#     <div style="margin-bottom: 20px;">
#         <strong>Theme:</strong> Therapeutic Targets of KRAS<br><br>
#         <strong>Summary:</strong><br>
#         KRAS is a significant oncogene with therapeutic targets that have been the focus of various studies. Sotorasib is one of the key agents that specifically inhibits the KRAS-G12C mutation, showing promise for treating patients with this particular mutation [125][147]. Additionally, immunotherapy has been linked to decreased disease progression in patients with KRAS mutant non-small cell lung cancer when treated with first-line immunotherapy [690]. Furthermore, computational biological modeling has indicated that overall survival rates improve for advanced KRAS mutant non-small cell lung cancer (NSCLC) patients undergoing PD-(L)1 immunotherapy [674]. However, it is crucial to note that in patients with KRAS mutations who received immune checkpoint inhibitors, there was no significant change in the progression-free survival compared to those with KRAS wild-type [420]. The therapeutic landscape for KRAS continues to evolve, with ongoing research aimed at enhancing treatment strategies for KRAS mutant cancers.
#     </div>
#     <hr>

# %%
cited_statements = {}
for citation in sorted(citations, key=int):
    citation_idx = int(citation) - 1
    cited_statements[citation_idx+1] = statements[citation_idx]

from IPython.display import display, HTML

def display_cited_statements(cited_statements):
    html_content = """
    <style>
        .cited-statements {
            font-family: Arial, sans-serif;
            border-collapse: collapse;
            width: 100%;
            margin-bottom: 20px;
        }
        .cited-statements td, .cited-statements th {
            border: 1px solid #ddd;
            padding: 8px;
        }
        .cited-statements tr:nth-child(even) {
            background-color: #f2f2f2;
        }
        .cited-statements tr:hover {
            background-color: #ddd;
        }
        .cited-statements th {
            padding-top: 12px;
            padding-bottom: 12px;
            text-align: left;
            background-color: #4CAF50;
            color: white;
        }
    </style>
    <table class="cited-statements">
        <tr>
            <th>Citation</th>
            <th>Statement</th>
        </tr>
    """
    
    for citation, statement in cited_statements.items():
        html_content += f"""
        <tr>
            <td>[{citation}]</td>
            <td>{statement.summary}, num_findings: {len(statement.finding_ids)}</td>
        </tr>
        """
    
    html_content += "</table>"
    
    display(HTML(html_content))

# Use the function
display_cited_statements(cited_statements)
# Out:
#     <style>
#         .cited-statements {
#             font-family: Arial, sans-serif;
#             border-collapse: collapse;
#             width: 100%;
#             margin-bottom: 20px;
#         }
#         .cited-statements td, .cited-statements th {
#             border: 1px solid #ddd;
#             padding: 8px;
#         }
#         .cited-statements tr:nth-child(even) {
#             background-color: #f2f2f2;
#         }
#         .cited-statements tr:hover {
#             background-color: #ddd;
#         }
#         .cited-statements th {
#             padding-top: 12px;
#             padding-bottom: 12px;
#             text-align: left;
#             background-color: #4CAF50;
#             color: white;
#         }
#     </style>
#     <table class="cited-statements">
#         <tr>
#             <th>Citation</th>
#             <th>Statement</th>
#         </tr>
#
#         <tr>
#             <td>[1]</td>
#             <td>KRAS mutations is associated with survival, but the strength of the effect is mixed., num_findings: 28</td>
#         </tr>
#
#         <tr>
#             <td>[2]</td>
#             <td>KRAS testing is associated with colorectal cancer prognosis, but the strength of the effect is mixed., num_findings: 37</td>
#         </tr>
#
#         <tr>
#             <td>[4]</td>
#             <td>KRAS G13D-variant is associated with distant metastatic colorectal tumor samples, but the strength of the effect is mixed., num_findings: 25</td>
#         </tr>
#
#         <tr>
#             <td>[5]</td>
#             <td>KRAS mutation is associated with survival from PDAC, but the strength of the effect is mixed., num_findings: 31</td>
#         </tr>
#
#         <tr>
#             <td>[6]</td>
#             <td>In most available studies, KRAS mutations is associated with increases in progression-free survival (of metastatic colorectal cancer)., num_findings: 28</td>
#         </tr>
#
#         <tr>
#             <td>[7]</td>
#             <td>In most available studies, KRAS mutations is associated with decreases in overall survival (of NSCLC patients)., num_findings: 19</td>
#         </tr>
#
#         <tr>
#             <td>[15]</td>
#             <td>In most available studies, KRAS mutations is associated with decreases in overall survival (among patients with non-small-cell lung cancer)., num_findings: 9</td>
#         </tr>
#
#         <tr>
#             <td>[19]</td>
#             <td>KRAS mutations is associated with Overall Survival (among patients with KRAS-mutated advanced colorectal cancer), but the strength of the effect is mixed., num_findings: 6</td>
#         </tr>
#
#         <tr>
#             <td>[21]</td>
#             <td>KRAS mutations is associated with disease dissemination (among colon cancer patients), but the strength of the effect is mixed., num_findings: 16</td>
#         </tr>
#
#         <tr>
#             <td>[52]</td>
#             <td>KRAS mutations is associated with increases in tumor grade., num_findings: 2</td>
#         </tr>
#
#         <tr>
#             <td>[56]</td>
#             <td>In every available study, KRAS mutations is associated with increases in tumor stage., num_findings: 8</td>
#         </tr>
#
#         <tr>
#             <td>[57]</td>
#             <td>GTP binds KRAS., num_findings: 11</td>
#         </tr>
#
#         <tr>
#             <td>[61]</td>
#             <td>KRAS mutations is associated with smokers, but the strength of the effect is mixed., num_findings: 2</td>
#         </tr>
#
#         <tr>
#             <td>[86]</td>
#             <td>KRAS binds RAF., num_findings: 2</td>
#         </tr>
#
#         <tr>
#             <td>[111]</td>
#             <td>KRAS increases the amount of Cyclin and phosphorylated ERK., num_findings: 3</td>
#         </tr>
#
#         <tr>
#             <td>[124]</td>
#             <td>KRAS is activated by MEK, RAS, ERK, RTK, p38, and 4 others., num_findings: 16</td>
#         </tr>
#
#         <tr>
#             <td>[125]</td>
#             <td>sotorasib inhibits KRAS-G12C., num_findings: 2</td>
#         </tr>
#
#         <tr>
#             <td>[147]</td>
#             <td>sotorasib inhibits KRASG12C mutant., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[159]</td>
#             <td>KRAS is bound by BRAF, SOS1, MYC, TP53, RHOA, and 5 others., num_findings: 16</td>
#         </tr>
#
#         <tr>
#             <td>[205]</td>
#             <td>KRAS positively regulates transcription, DNA-templated, apoptotic process, epithelial to mesenchymal transition, response to drug, oncogene-induced cell senescence, and 16 others., num_findings: 115</td>
#         </tr>
#
#         <tr>
#             <td>[209]</td>
#             <td>KRAS activates HNRNP, TGFB, NFkappaB, ERK, RAS, and 12 others., num_findings: 77</td>
#         </tr>
#
#         <tr>
#             <td>[245]</td>
#             <td>KRAS expression is associated with increases in Cyclin D1 expression., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[250]</td>
#             <td>KRAS expression is associated with increases in Ki-67 expression., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[257]</td>
#             <td>KRASG12D mutation is associated with increases in the rate of metastatic tumors., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[276]</td>
#             <td>KRAS expression is associated with increases in Bcl2 expression., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[307]</td>
#             <td>KRAS (Kirsten rat sarcoma-2 virus) gene is associated with increases in the rate of diagnosis of pancreatic cancer., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[420]</td>
#             <td>KRAS mutated patients who received Immune checkpoint inhibitor [vs KRAS-wt patients who received Immune checkpoint inhibitor] is associated with no change in the mean of progression-free survival (PFS)., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[488]</td>
#             <td>Patients with G12C-mutated tumors [vs Patients with other -mutated tumors] is associated with increases in the mean of Frequency of metastasectomies and ablations., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[548]</td>
#             <td>KRAS mutations and NF-κB activation is associated with increases in overall survival among colorectal cancer patients., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[615]</td>
#             <td>Kirsten Ras -mutated colorectal cancer is associated with decreases in disease-specific survival (among individuals diagnosed with colorectal cancer)., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[674]</td>
#             <td>computational biological modeling-assessed overall survival is associated with increases in actual overall survival (of advanced KRASMUT NSCLC patients treated with PD-(L)1 immunotherapy)., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[690]</td>
#             <td>immunotherapy is associated with decreases in disease progression (among KRAS mutant non-small cell lung cancer patients treated with first-line immunotherapy)., num_findings: 1</td>
#         </tr>
#
#         <tr>
#             <td>[873]</td>
#             <td>V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog () status is associated with increases in radioresistance in non-small cell lung cancer (NSCLC)., num_findings: 1</td>
#         </tr>
#         </table>

# %%
statistical_findings_df
# Out:
#               id  flagged finding_type  \
# 0     EstL4te5Fy    False  statistical
# 1     Xdx-GYv-SI    False  statistical
# 2     aVzZHXnzgG    False  statistical
# 3     lRN8XzszRy    False  statistical
# 4     RLDH9DN9AI    False  statistical
# ...          ...      ...          ...
# 2855  2ksRkgyZ3B    False  statistical
# 2856  btogrD2nfj    False  statistical
# 2857  KPOK212_F_    False  statistical
# 2858  Px8A2T1tqn    False  statistical
# 2859  bwyrwEeDH5    False  statistical
#
#                                                 summary  \
# 0     patients with KRAS mutation (KRASm) [vs patien...
# 1     patients with KRAS mutation (KRASm) [vs patien...
# 2     Greenlandic population diagnosed with CRC in 2...
# 3     Tumors with invasive implants/LGSC [vs Tumors ...
# 4     Patients with KRAS mutation [vs Patients witho...
# ...                                                 ...
# 2855  Well-Differentiated Neuroendocrine Carcinoma (...
# 2856  Well-Differentiated Neuroendocrine Carcinoma (...
# 2857  Ulcerative colitis with low (UC-LR) group [vs ...
# 2858  Iperihilar cholangiocarcinoma group [vs Eperih...
# 2859  Iperihilar cholangiocarcinoma group [vs Eperih...
#
#                                                 topic_1  \
# 0       {'id': '6YmesoiLnT', 'name': 'ras gene family'}
# 1       {'id': '6YmesoiLnT', 'name': 'ras gene family'}
# 2     {'id': 'McFqOyw_JT', 'name': 'colorectal neopl...
# 3                                                  None
# 4       {'id': '6YmesoiLnT', 'name': 'ras gene family'}
# ...                                                 ...
# 2855  {'id': 'o4y8pYY8y4', 'name': 'neuroendocrine c...
# 2856  {'id': 'o4y8pYY8y4', 'name': 'neuroendocrine c...
# 2857  {'id': 'ad6dwiIOQU', 'name': 'ulcerative colit...
# 2858  {'id': '1kbmy7R4g3', 'name': 'cholangiocarcino...
# 2859  {'id': '1kbmy7R4g3', 'name': 'cholangiocarcino...
#
#                                                 topic_2  \
# 0     {'id': 'W6qftQ1CpV', 'name': 'progression-free...
# 1         {'id': 'bxy3dykVii', 'name': 'survival rate'}
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2855           {'id': 'vUwiaNEBVo', 'name': 'survival'}
# 2856                                               None
# 2857                                               None
# 2858    {'id': '6YmesoiLnT', 'name': 'ras gene family'}
# 2859           {'id': 'OXt6jy0wqh', 'name': 'neoplasm'}
#
#                                              variable_1  \
# 0     {'id': 'x0aW3B9GFQ', 'name': 'patients with KR...
# 1     {'id': 'x0aW3B9GFQ', 'name': 'patients with KR...
# 2     {'id': 'x2Amrqb9F_', 'name': 'Greenlandic popu...
# 3     {'id': '2prvEXw196', 'name': 'Tumors with inva...
# 4     {'id': 'eQYB4N9cdz', 'name': 'Patients with KR...
# ...                                                 ...
# 2855  {'id': 'orGx5Tl22X', 'name': 'Well-Differentia...
# 2856  {'id': 'orGx5Tl22X', 'name': 'Well-Differentia...
# 2857  {'id': 'se2WiDxXg1', 'name': 'Ulcerative colit...
# 2858  {'id': 'n-keehxvUo', 'name': 'Iperihilar chola...
# 2859  {'id': 'n-keehxvUo', 'name': 'Iperihilar chola...
#
#                                              variable_2  \
# 0     {'id': '_4sqTSr6ev', 'name': 'Progression-free...
# 1     {'id': 'NGPYuxmNnf', 'name': 'Overall survival...
# 2     {'id': 'Y6wHsRWAzk', 'name': 'Frequency of KRA...
# 3         {'id': 'ZgwayC7lHS', 'name': 'KRAS mutation'}
# 4     {'id': 'WpuLmXhAFc', 'name': 'High-stage disea...
# ...                                                 ...
# 2855    {'id': 'BjqavCwVTn', 'name': 'Median Survival'}
# 2856  {'id': 'erHxGvVhgN', 'name': 'Rb Immunopositiv...
# 2857  {'id': 'QK7xSZSskB', 'name': 'frequency of p53...
# 2858  {'id': 'rsidNbHkow', 'name': 'mutation frequen...
# 2859         {'id': 'gI1vvo6IYo', 'name': 'tumor size'}
#
#                                                   study  \
# 0     {'id': 'g32gaM6OSN', 'doi': '10.1016/j.ejca.20...
# 1     {'id': 'g32gaM6OSN', 'doi': '10.1016/j.ejca.20...
# 2     {'id': 'zkgmtG77Sm', 'doi': '10.1111/apm.13254...
# 3     {'id': 'Bf2AmtzS8F', 'doi': '10.1007/s00428-02...
# 4     {'id': 'Bf2AmtzS8F', 'doi': '10.1007/s00428-02...
# ...                                                 ...
# 2855  {'id': 'C454YGhYw5', 'doi': '10.1007/s00535-01...
# 2856  {'id': 'C454YGhYw5', 'doi': '10.1007/s00535-01...
# 2857  {'id': 'On_W7IeWEg', 'doi': '10.1016/j.crohns....
# 2858  {'id': 'XkGd0Cqrkf', 'doi': '10.5858/arpa.2023...
# 2859  {'id': 'XkGd0Cqrkf', 'doi': '10.5858/arpa.2023...
#
#                       statistic_type  statistic_value  ci_upper  ci_lower  \
# 0     mean_difference_unstandardized           -24.00       NaN       NaN
# 1     mean_difference_unstandardized           -29.70       NaN       NaN
# 2     mean_difference_unstandardized            16.00       NaN       NaN
# 3     mean_difference_unstandardized            17.00       NaN       NaN
# 4     mean_difference_unstandardized            -8.00       NaN       NaN
# ...                              ...              ...       ...       ...
# 2855  mean_difference_unstandardized            41.00       NaN       NaN
# 2856  mean_difference_unstandardized            86.00       NaN       NaN
# 2857  mean_difference_unstandardized           -46.70       NaN       NaN
# 2858  mean_difference_unstandardized            16.70       NaN       NaN
# 2859  mean_difference_unstandardized             2.17       NaN       NaN
#
#       p_value
# 0       0.003
# 1       0.004
# 2       0.001
# 3       0.310
# 4       0.640
# ...       ...
# 2855    0.227
# 2856    0.015
# 2857    0.050
# 2858    0.030
# 2859    0.002
#
# [2860 rows x 14 columns]

# %%
mechanistic_findings_df
# Out:
#                id  flagged finding_type summary  \
# 0      b09sf4KHUi    False  mechanistic    None
# 1      WYmMWF17BM    False  mechanistic    None
# 2      AP15COQeJG    False  mechanistic    None
# 3      SmxVCGcWgm    False  mechanistic    None
# 4      052ZO0DiVI    False  mechanistic    None
# ...           ...      ...          ...     ...
# 12152  Y4ECr2OGNk    False  mechanistic    None
# 12153  tWgFt2B1kh    False  mechanistic    None
# 12154  YF-KRb8-0K    False  mechanistic    None
# 12155  7doEcuQC5j    False  mechanistic    None
# 12156  FXVvnMhFBH    False  mechanistic    None
#
#                                                  topic_1  \
# 0                   {'id': 'ZID6hiZiyU', 'name': 'KRAS'}
# 1                 {'id': '51IRfGK6wf', 'name': 'PTPN11'}
# 2                   {'id': 'gVu5cKJraO', 'name': 'sos1'}
# 3      {'id': 'MT7T8mj3pO', 'name': 'signal transduct...
# 4                                                   None
# ...                                                  ...
# 12152               {'id': 'gVu5cKJraO', 'name': 'sos1'}
# 12153             {'id': '51IRfGK6wf', 'name': 'PTPN11'}
# 12154               {'id': 'ZID6hiZiyU', 'name': 'KRAS'}
# 12155                {'id': 'SR54laVCr_', 'name': 'EGF'}
# 12156                {'id': 'SR54laVCr_', 'name': 'EGF'}
#
#                                                  topic_2  \
# 0               {'id': 'OXt6jy0wqh', 'name': 'neoplasm'}
# 1               {'id': 'OXt6jy0wqh', 'name': 'neoplasm'}
# 2               {'id': 'OXt6jy0wqh', 'name': 'neoplasm'}
# 3      {'id': 'EukymkmUae', 'name': 'cell population ...
# 4      {'id': '9dQYb_73YK', 'name': 'guanosine tripho...
# ...                                                  ...
# 12152               {'id': 'Ot6TE8R2_D', 'name': 'gnl3'}
# 12153               {'id': 'Ot6TE8R2_D', 'name': 'gnl3'}
# 12154               {'id': 'Ot6TE8R2_D', 'name': 'gnl3'}
# 12155                                               None
# 12156               {'id': 'GTS8LJii5O', 'name': 'NRAS'}
#
#                                               variable_1  \
# 0                   {'id': 'EGWlup-mGE', 'name': 'KRAS'}
# 1                 {'id': 'Bkx0cIK3BI', 'name': 'PTPN11'}
# 2                   {'id': 'clskjHOzCy', 'name': 'SOS1'}
# 3      {'id': 'CRKgrii9F1', 'name': 'signal transduct...
# 4                    {'id': 'A8kBJfuB6f', 'name': 'GDP'}
# ...                                                  ...
# 12152               {'id': 'clskjHOzCy', 'name': 'SOS1'}
# 12153             {'id': 'Bkx0cIK3BI', 'name': 'PTPN11'}
# 12154               {'id': 'EGWlup-mGE', 'name': 'KRAS'}
# 12155                {'id': 'JHOJvzDt5P', 'name': 'EGF'}
# 12156                {'id': 'JHOJvzDt5P', 'name': 'EGF'}
#
#                                               variable_2  \
# 0              {'id': 'LYaiZ1yCbp', 'name': 'Neoplasms'}
# 1              {'id': 'LYaiZ1yCbp', 'name': 'Neoplasms'}
# 2              {'id': 'LYaiZ1yCbp', 'name': 'Neoplasms'}
# 3      {'id': 'QKx3aWctDv', 'name': 'cell population ...
# 4                    {'id': 'h-I7ZjbRuW', 'name': 'GTP'}
# ...                                                  ...
# 12152               {'id': 'q8pSBYLfyB', 'name': 'GNL3'}
# 12153               {'id': 'q8pSBYLfyB', 'name': 'GNL3'}
# 12154               {'id': 'q8pSBYLfyB', 'name': 'GNL3'}
# 12155       {'id': 'SbOltNnC1i', 'name': 'localization'}
# 12156               {'id': 'mhDPEpFj_d', 'name': 'NRAS'}
#
#                                                    study mechanism_type
# 0      {'id': 'QzU6dhsyHq', 'doi': '10.3390/ijms23084...     Activation
# 1      {'id': 'yx8-pkVyqa', 'doi': '10.1016/j.ctrv.20...     Activation
# 2      {'id': 'yx8-pkVyqa', 'doi': '10.1016/j.ctrv.20...     Activation
# 3      {'id': 'DWgWf3yLLI', 'doi': '10.1007/s40291-02...     Activation
# 4      {'id': 'c6dhOLOWfo', 'doi': '10.1111/joim.1305...     Inhibition
# ...                                                  ...            ...
# 12152  {'id': 'LZfBBg87Oa', 'doi': '10.1016/j.ejmg.20...     Activation
# 12153  {'id': 'LZfBBg87Oa', 'doi': '10.1016/j.ejmg.20...     Activation
# 12154  {'id': 'LZfBBg87Oa', 'doi': '10.1016/j.ejmg.20...     Activation
# 12155  {'id': '855od3y5P8', 'doi': '10.1074/jbc.m109....     Activation
# 12156  {'id': '855od3y5P8', 'doi': '10.1074/jbc.m109....     Activation
#
# [12157 rows x 10 columns]

# %%
statements_df
# Out:
#                                                 summary  \
# 0     KRAS mutations is associated with survival, bu...
# 1     KRAS testing is associated with colorectal can...
# 2     mutant KRAS is associated with response (of KR...
# 3     KRAS G13D-variant is associated with distant m...
# 4     KRAS mutation is associated with survival from...
# ...                                                 ...
# 1746  rat sarcoma wild-type is associated with decre...
# 1747    RHOA positively regulates cell differentiation.
# 1748                       CSNK1 phosphorylates LGALS3.
# 1749  oligometastatic status is associated with incr...
# 1750  skip N2 metastases without N1 is associated wi...
#
#                                             finding_ids finding_type
# 0     [Xdx-GYv-SI, URDtceDtrO, zi9ZoiyZcl, SdaTJ6vhj...  statistical
# 1     [_Stft2XAhB, GPmZ6bT3o2, uKTGMh3OsI, 1eyidH5jc...  statistical
# 2     [7AcXCurdDm, 6iGuNkIUco, 7mMeYmRRx-, wSdJXizct...  statistical
# 3     [lxCUYzDfMf, XBEpFPNXld, d5QqM7piU3, QQl9dF56R...  statistical
# 4     [H4Yt7a7gZd, ilDPCNz7jM, 19A4wVruq4, 19A4wVruq...  statistical
# ...                                                 ...          ...
# 1746                                       [xWp0gYrjux]  statistical
# 1747                                       [3uYORZbhSU]  mechanistic
# 1748                                       [mbbUs2Y6e5]  mechanistic
# 1749                                       [FciQ-k9Ue3]  statistical
# 1750                           [LtDkJr9MvX, LEQOEKBY7C]  statistical
#
# [1751 rows x 3 columns]
